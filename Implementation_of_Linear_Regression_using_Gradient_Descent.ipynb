# %% [markdown]
# <a href="https://colab.research.google.com/github/pavankumarkasula73/PatternRecognition/blob/main/Implementation_of_Linear_Regression_using_Gradient_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Import Libraries**

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # **Generate Example Data**

# %%
# Set the random seed for reproducibility
np.random.seed(42)

# Generate 100 random data points
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# Plot the data
plt.scatter(X, y)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Generated Data")
plt.show()

# %% [markdown]
# # **Prepare the Data**

# %%
# Add the intercept term to each instance
X_b = np.c_[np.ones((100, 1)), X]

# %% [markdown]
# # **Initialize Parameters**

# %%
# Random initialization of theta
theta = np.random.randn(2, 1)

# %% [markdown]
# # **Define Gradient Descent Parameters**

# %%
# Gradient Descent parameters
learning_rate = 0.1
n_iterations = 1000
m = len(X_b)

# %% [markdown]
# # **Implement Gradient Descent**

# %%
# Gradient Descent loop
for iteration in range(n_iterations):
    gradients = 2/m * X_b.T.dot(X_b.dot(theta) - y)
    theta = theta - learning_rate * gradients

# %% [markdown]
# # **Output the Results**

# %%
print("Theta found by Gradient Descent:", theta)
# Out:
# Theta found by Gradient Descent: [[4.21509616]
#  [2.77011339]]

# %% [markdown]
# # **Visualize the Results**

# %%
# Plot the data and the regression line
plt.plot(X, y, "b.")
plt.plot(X, X_b.dot(theta), "r-")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Linear Regression using Gradient Descent")
plt.show()
